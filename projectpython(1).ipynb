# %%
import pandas as pd

# %%
#importing the dataset
df=pd.read_csv(r"C:\Users\Godfrey Ike\Documents\HIIT\EXCEL HIIT\listings.csv",encoding='latin1')
autostrip=True
# Out:
# C:\Users\Godfrey Ike\AppData\Local\Temp\ipykernel_9080\1074937185.py:2: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\Godfrey Ike\Documents\HIIT\EXCEL HIIT\listings.csv",encoding='latin1')

# %%
df_copy=df.copy()

# %%
df2=pd.read_csv(r"C:\Users\Godfrey Ike\Documents\HIIT\EXCEL HIIT\reviews.csv")
autostrip=True
df2_copy=df2.copy
df2
# Out:
#          listing_id  review_id        date  reviewer_id
# 0             11798  330265172  2018-09-30     11863072
# 1             15383  330103585  2018-09-30     39147453
# 2             16455  329985788  2018-09-30      1125378
# 3             17919  330016899  2018-09-30    172717984
# 4             26827  329995638  2018-09-30     17542859
# ...             ...        ...         ...          ...
# 5373138    47779342  726766332  2021-01-25    283094516
# 5373139    47823964  727963021  2021-01-31     76411977
# 5373140    47896175  728548625  2021-02-02     71370946
# 5373141    47900451  727399287  2021-01-29    109011160
# 5373142    47998038  730320626  2021-02-11    276790978
#
# [5373143 rows x 4 columns]

# %%
#merging the two dataset together
merged_df=pd.merge(df,df2,on="listing_id")
merged_df
# Out:
#          listing_id                                               name  \
# 0            281420     Beautiful Flat in le Village Montmartre, Paris
# 1            281420     Beautiful Flat in le Village Montmartre, Paris
# 2           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# 3           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# 4           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# ...             ...                                                ...
# 5373138    38683356            Nice and cosy mini-appartement in Paris
# 5373139    38683356            Nice and cosy mini-appartement in Paris
# 5373140    39659000  Charming apartment near Rue Saint Maur / Oberk...
# 5373141    40219504        Cosy apartment with view on Canal St Martin
# 5373142    40219504        Cosy apartment with view on Canal St Martin
#
#           host_id  host_since                 host_location  \
# ...

# %%
#checking the percentage of missing values
missing_values=merged_df.isna().mean()*100
print(missing_values)
# Out:
# listing_id                      0.000000
# name                            0.006197
# host_id                         0.000000
# host_since                      0.073309
# host_location                   0.147214
# host_response_time             27.463125
# host_response_rate             27.463125
# host_acceptance_rate           13.929222
# host_is_superhost               0.073309
# host_total_listings_count       0.073309
# host_has_profile_pic            0.073309
# host_identity_verified          0.073309
# neighbourhood                   0.000000
# district                       84.222884
# city                            0.000000
# latitude                        0.000000
# longitude                       0.000000
# property_type                   0.000000
# room_type                       0.000000
# accommodates                    0.000000
# bedrooms                       10.076281
# amenities                       0.000000
# price                           0.000000
# ...

# %%
#deleting the district column
dropped_district=merged_df.drop("district",axis=1)
merged_df=dropped_district

# %%
#dropping the null values in host_response_time
merged_df.dropna(subset=['host_response_time'],inplace=True)

# %%
#dropping the null values in host_response_rate
merged_df.dropna(subset=['host_response_rate'],inplace=True)

# %%
#dropping the null values in host_acceptance_rate
merged_df.dropna(subset=['host_acceptance_rate'],inplace=True)

# %%
#dropping the null values in bedroom
merged_df.dropna(subset=['bedrooms'],inplace=True)

# %%
#dropping the null values in host_since
merged_df.dropna(subset=['host_since'],inplace=True)

# %%
#dropping the null values in host_is_superhost
merged_df.dropna(subset=['host_is_superhost'],inplace=True)

# %%
#dropping the null values in the host_total_listings_count

merged_df.dropna(subset=['host_total_listings_count'],inplace=True)

# %%
#dropping the null values in the host_has_profile_pic

merged_df.dropna(subset=['host_has_profile_pic'],inplace=True)

# %%
#dropping the null values in the host_identity_verified

merged_df.dropna(subset=['host_identity_verified'],inplace=True)

# %%
#dropping the null values in the review_scores_rating
merged_df.dropna(subset=['review_scores_rating'],inplace=True)

# %%
#dropping the null values in the review_scores_accuracy
merged_df.dropna(subset=['review_scores_accuracy'],inplace=True)

# %%
#dropping the null values in the review_scores_cleanliness
merged_df.dropna(subset=['review_scores_cleanliness'],inplace=True)

# %%
#dropping the null values in the review_scores_checkin
merged_df.dropna(subset=['review_scores_checkin'],inplace=True)

# %%
#dropping the null values in the review_scores_communication
merged_df.dropna(subset=['review_scores_communication'],inplace=True)

# %%
#dropping the null values in review_scores_location
merged_df.dropna(subset=['review_scores_location'],inplace=True)

# %%
#dropping the null values in review_scores_value
merged_df.dropna(subset=['review_scores_value'],inplace=True)

# %%
#renaming the name column to be description
new_column={'name':'description'}
merged_df=merged_df.rename(columns=new_column)
merged_df.head()
# Out:
#         listing_id                                        description  \
# 279903    39849253                  Warm and Cosy Flat for 2 in Paris
# 279904    39849253                  Warm and Cosy Flat for 2 in Paris
# 279905    39849253                  Warm and Cosy Flat for 2 in Paris
# 279906    39849253                  Warm and Cosy Flat for 2 in Paris
# 279907    40436816  Bright apartment in PIGALLE - Professional Cle...
#
#           host_id  host_since host_location host_response_time  \
# 279903  305389411  2019-10-30            GB     within an hour
# 279904  305389411  2019-10-30            GB     within an hour
# 279905  305389411  2019-10-30            GB     within an hour
# 279906  305389411  2019-10-30            GB     within an hour
# 279907  312774780  2019-11-28            IE     within an hour
#
#         host_response_rate  host_acceptance_rate host_is_superhost  \
# 279903                 1.0                   1.0                 f
# ...

# %%
#dropping the null values in the column
merged_df.dropna(subset=['description'],inplace=True)

# %%
#removing the string that contains Â in the name column
char_replace=merged_df[~merged_df['description'].str.contains("Â")]
merged_df=char_replace

# %%
#deleting the host_location 
dropped_location=merged_df.drop("host_location",axis=1)
merged_df=dropped_location

# %%
#checking the percentage of missing values
missing_values=merged_df.isna().mean()*100
print(missing_values)
# Out:
# listing_id                     0.0
# description                    0.0
# host_id                        0.0
# host_since                     0.0
# host_response_time             0.0
# host_response_rate             0.0
# host_acceptance_rate           0.0
# host_is_superhost              0.0
# host_total_listings_count      0.0
# host_has_profile_pic           0.0
# host_identity_verified         0.0
# neighbourhood                  0.0
# city                           0.0
# latitude                       0.0
# longitude                      0.0
# property_type                  0.0
# room_type                      0.0
# accommodates                   0.0
# bedrooms                       0.0
# amenities                      0.0
# price                          0.0
# minimum_nights                 0.0
# maximum_nights                 0.0
# review_scores_rating           0.0
# review_scores_accuracy         0.0
# review_scores_cleanliness      0.0
# review_scores_checkin          0.0
# ...

# %%
merged_df
# Out:
#          listing_id                                        description  \
# 279903     39849253                  Warm and Cosy Flat for 2 in Paris
# 279904     39849253                  Warm and Cosy Flat for 2 in Paris
# 279905     39849253                  Warm and Cosy Flat for 2 in Paris
# 279906     39849253                  Warm and Cosy Flat for 2 in Paris
# 279907     40436816  Bright apartment in PIGALLE - Professional Cle...
# ...             ...                                                ...
# 5234958    44273734          Charming duplex near JARDIN DU LUXEMBOURG
# 5234959    44339814                 Appartement piscine place d'Italie
# 5234960    45200617          Cozy Montmartre flat near Le Moulin Rouge
# 5234961    46673032  Moderne-ancien- jungle urbaine - proche Montma...
# 5234962    46673032  Moderne-ancien- jungle urbaine - proche Montma...
#
#            host_id  host_since  host_response_time  host_response_rate  \
# ...

# %%
 merged_df.to_csv('project_python.csv',index=False)
